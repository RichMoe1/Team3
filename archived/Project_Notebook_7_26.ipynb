# %% [markdown]
# # 50 Years of Music Trends
#
# ## Objective
# * Analyze lyrics from billboard top 100 songs over 50 years to identify trends
# * Statement: Has the sentiments of popular lyrics changed over time?
#
# ## Hypothesis
# * Ha1 = the sentiments of popular lyrics has become more negative over time
# * Ha2 = the sentiments of popular lyrics has become more positive over time
# * Ho = no change in the sentiments of popular lyrics over time
#
# ## Sources
# * musixmatch source: https://developer.musixmatch.com/documentation/api-reference/track-lyrics-get <br/>
# * musixmatch python: https://github.com/hudsonbrendon/python-musixmatch <br/>
# * billboard python: https://github.com/guoguo12/billboard-charts<br/>

# %%
# Dependency library
import numpy as np
import pandas as pd
import random
from datetime import datetime, timedelta
import matplotlib.pyplot as plt

# API Calls
import billboard
from musixmatch import Musixmatch

# API Keys
from musixmatch_api import api_key

# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Generate a (pseudo) random list of (almost all) dates in string format to fit musixmatch parameter

date_list = []
min_year = 1968
error_counter = 0

for i in range(50):
    try:
        # RANDOM date generation
        month_rand = str(random.randint(1,12))
        if len(month_rand) ==1:
            # PAD single digit numbers with a leading 0
            month_rand = month_rand.zfill(2)
            
        day_rand = str(random.randint(1,28))
        if len(day_rand) == 1:
            day_rand = day_rand.zfill(2)
        
        # STRINGIFY the result for the musixmatch parameter
        date_rand = str(f'{min_year}-{month_rand}-{day_rand}')
        
        # APPEND result to date_list
        date_list.append(date_rand)
        
        #INCREMENT the year
        min_year = min_year + 1
        
    except ValueError:
        error_counter = error_counter + 1
    
date_list
# Out:
# ['1968-05-13',
#  '1969-09-19',
#  '1970-02-09',
#  '1971-05-02',
#  '1972-03-14',
#  '1973-06-12',
#  '1974-10-04',
#  '1975-08-15',
#  '1976-08-11',
#  '1977-04-01',
#  '1978-10-06',
#  '1979-01-11',
#  '1980-09-15',
#  '1981-11-04',
#  '1982-08-26',
#  '1983-07-24',
#  '1984-07-20',
#  '1985-08-21',
#  '1986-02-23',
#  '1987-01-08',
#  '1988-11-23',
#  '1989-02-19',
#  '1990-09-08',
#  '1991-02-03',
#  '1992-09-05',
#  '1993-09-23',
#  '1994-11-28',
#  '1995-09-11',
#  '1996-08-05',
#  '1997-04-04',
#  '1998-09-04',
#  '1999-06-28',
#  '2000-03-25',
#  '2001-12-21',
#  '2002-02-19',
#  '2003-09-03',
#  '2004-11-20',
#  '2005-01-18',
#  '2006-05-12',
#  '2007-06-23',
#  '2008-10-14',
#  '2009-06-11',
#  '2010-07-12',
#  '2011-03-13',
#  '2012-10-07',
#  '2013-02-03',
#  '2014-08-25',
#  '2015-07-17',
#  '2016-12-25',
#  '2017-04-27']

# %%
# Return top 100 billboard songs for each date in random list generated above

billboard_list = 'hot-100'
col_names = ['Song','Artist','Date']
chart_df = pd.DataFrame(columns = col_names)

for date in date_list:
    chart = billboard.ChartData(billboard_list,date)
    for row in chart:
        # EMPTY the list placeholder used to create the dataframe
        chart_list = []
        # CLEAN and convert the billboard object
        chart_list.append(str(row).replace("'","",1))
        temp_df = pd.DataFrame(chart_list)
        temp_df = temp_df[0].str.split("' by ",expand=True)
        temp_df = temp_df.rename(columns={0:"Song",1:"Artist"})
        temp_df['Date'] = date
        
        # APPEND the temp_df in the current loop location to the chart_df
        chart_df = chart_df.append(temp_df)

# REMOVE duplicates and RESET index from the resulting dataframe        
chart_df = chart_df.drop_duplicates().reset_index(drop=True)

# PREVIEW
print(len(chart_df))
chart_df.head()
# Out:
# 5000
#                              Song                                     Artist  \
# 0                      Tighten Up                   Archie Bell & The Drells
# 1                   Mrs. Robinson                          Simon & Garfunkel
# 2                           Honey                            Bobby Goldsboro
# 3  The Good, The Bad And The Ugly  Hugo Montenegro, His Orchestra And Chorus
# 4             A Beautiful Morning                                The Rascals
#
#          Date
# 0  1968-05-13
# 1  1968-05-13
# 2  1968-05-13
# 3  1968-05-13
# 4  1968-05-13

# %%
# SPLIT the date values in the dataframe for plotting and analysis purposes

chart_df['Year'], chart_df['Month'], chart_df['Day'] = chart_df['Date'].str.split('-').str

# PREVIEW
chart_df.head()
# Out:
#                              Song                                     Artist  \
# 0                      Tighten Up                   Archie Bell & The Drells
# 1                   Mrs. Robinson                          Simon & Garfunkel
# 2                           Honey                            Bobby Goldsboro
# 3  The Good, The Bad And The Ugly  Hugo Montenegro, His Orchestra And Chorus
# 4             A Beautiful Morning                                The Rascals
#
#          Date  Year Month Day
# 0  1968-05-13  1968    05  13
# 1  1968-05-13  1968    05  13
# 2  1968-05-13  1968    05  13
# 3  1968-05-13  1968    05  13
# 4  1968-05-13  1968    05  13

# %%
# Retrieve lyrics from MusixMatch API based on song and artist in above dataframe

musixmatch = Musixmatch(api_key)
lyrics_list = []
error_counter = 0

# LOOP through the data frame and use song title and artist name to search for lyrics in musixmatch
for x in range(len(chart_df)):
    
    # ERROR HANDLING in case a song queries returns 'null' from musixmatch
    try:
        # GRAB the lyrics based on location (iloc) in chart_df
        song_search = chart_df.iloc[x,0]
        artist_search = chart_df.iloc[x,1]
        lyrics = musixmatch.matcher_lyrics_get(q_artist=artist_search,
                                               q_track=song_search)['message']['body']['lyrics']['lyrics_body']
        
        # FORMATTING to truncate the nonsense at the end of the lyrics from MusixMatch
        song_length = len(lyrics)
        endpoint = len("******* This Lyrics is NOT for Commercial use *******\n(1409617829201)")
        lyrics = lyrics.replace("\n", " ")
        lyrics = str(lyrics[:song_length-endpoint])
        
        # APPEND lyrics to lyrics_list
        lyrics_list.append(lyrics)
        
    except:
        error_counter = error_counter + 1
        lyrics_list.append('MUSIXMATCH_NA')

# CREATE new column in chart_df
chart_df['Lyrics'] = lyrics_list
chart_df.head()
# Out:
#                              Song                                     Artist  \
# 0                      Tighten Up                   Archie Bell & The Drells
# 1                   Mrs. Robinson                          Simon & Garfunkel
# 2                           Honey                            Bobby Goldsboro
# 3  The Good, The Bad And The Ugly  Hugo Montenegro, His Orchestra And Chorus
# 4             A Beautiful Morning                                The Rascals
#
#          Date  Year Month Day         Lyrics
# 0  1968-05-13  1968    05  13  MUSIXMATCH_NA
# 1  1968-05-13  1968    05  13  MUSIXMATCH_NA
# 2  1968-05-13  1968    05  13  MUSIXMATCH_NA
# 3  1968-05-13  1968    05  13  MUSIXMATCH_NA
# 4  1968-05-13  1968    05  13  MUSIXMATCH_NA

# %%
clean_chart_df = chart_df[chart_df['Lyrics'] != "" or != "MUSIXMATCH_NA"].reset_index(drop=True)
clean_chart_df
# Out:
#                                                Song  \
# 0                                        Tighten Up
# 1                                     Mrs. Robinson
# 2                                             Honey
# 3                    The Good, The Bad And The Ugly
# 4                               A Beautiful Morning
# 5                                  Cowboys To Girls
# 6                                Love Is All Around
# 7                                       The Unicorn
# 8                                        Young Girl
# 9                   Do You Know The Way To San José
# 10                        Shoo-Be-Doo-Be-Doo-Da-Day
# 11                                  Cry Like A Baby
# 12                            Take Time To Know Her
# 13                Ain't Nothing Like The Real Thing
# 14                                     Lady Madonna
# 15                                 Summertime Blues
# 16                                I Got The Feelin'
# 17                                     Funky Street
# 18                                        Mony Mony
# 19                          Like To Get To Know You
# 20                                     Ain't No Way
# 21                               She's Lookin' Good
# 22                                    Soul Serenade
# 23                                Sweet Inspiration
# 24    I Could Never Love Another (After Loving You)
# 25                                          Delilah
# 26                         The Happy Song (Dum-Dum)
# 27                    I Will Always Think About You
# 28                            If I Were A Carpenter
# 29                     Does Your Mama Know About Me
# ...                                             ...
# 4970                                        Deja Vu
# 4971                                     Free Smoke
# 4972                                       Yeah Boy
# 4973                                  Unforgettable
# 4974                                       Drowning
# 4975                                  First Day Out
# 4976                             Road Less Traveled
# 4977                                        The One
# 4978                                Everyday We Lit
# 4979                            Scared To Be Lonely
# 4980                                    Craving You
# 4981                                     Good Drank
# 4982                                          Draco
# 4983                                           Blem
# 4984                                  You Look Good
# 4985                                     How Not To
# 4986                                      No Frauds
# 4987                                         Prblms
# 4988                                           Cake
# 4989                            Think A Little Less
# 4990                                  Teenage Fever
# 4991                    Bar At The End Of The World
# 4992                                 You're Welcome
# 4993                                     At My Best
# 4994                                 Still Got Time
# 4995                                Subeme La Radio
# 4996                                           Weak
# 4997                                How Far I'll Go
# 4998                                  If I Told You
# 4999                                      Flatliner
#
#                                                  Artist        Date  Year  \
# 0                              Archie Bell & The Drells  1968-05-13  1968
# 1                                     Simon & Garfunkel  1968-05-13  1968
# 2                                       Bobby Goldsboro  1968-05-13  1968
# 3             Hugo Montenegro, His Orchestra And Chorus  1968-05-13  1968
# 4                                           The Rascals  1968-05-13  1968
# 5                                         The Intruders  1968-05-13  1968
# 6                                            The Troggs  1968-05-13  1968
# 7                                      The Irish Rovers  1968-05-13  1968
# 8                  The Union Gap Featuring Gary Puckett  1968-05-13  1968
# 9                                        Dionne Warwick  1968-05-13  1968
# 10                                        Stevie Wonder  1968-05-13  1968
# 11                                         The Box Tops  1968-05-13  1968
# 12                                         Percy Sledge  1968-05-13  1968
# 13                          Marvin Gaye & Tammi Terrell  1968-05-13  1968
# 14                                          The Beatles  1968-05-13  1968
# 15                                           Blue Cheer  1968-05-13  1968
# 16                    James Brown And The Famous Flames  1968-05-13  1968
# 17                                        Arthur Conley  1968-05-13  1968
# 18                        Tommy James And The Shondells  1968-05-13  1968
# 19                                  Spanky And Our Gang  1968-05-13  1968
# 20                                      Aretha Franklin  1968-05-13  1968
# 21                                       Wilson Pickett  1968-05-13  1968
# 22                                      Willie Mitchell  1968-05-13  1968
# 23                               The Sweet Inspirations  1968-05-13  1968
# 24                                      The Temptations  1968-05-13  1968
# 25                                            Tom Jones  1968-05-13  1968
# 26                                         Otis Redding  1968-05-13  1968
# 27                                   The New Colony Six  1968-05-13  1968
# 28                                            Four Tops  1968-05-13  1968
# 29                        Bobby Taylor & The Vancouvers  1968-05-13  1968
# ...                                                 ...         ...   ...
# 4970                                            J. Cole  2017-04-27  2017
# 4971                                              Drake  2017-04-27  2017
# 4972                                   Kelsea Ballerini  2017-04-27  2017
# 4973                  French Montana Featuring Swae Lee  2017-04-27  2017
# 4974       A Boogie Wit da Hoodie Featuring Kodak Black  2017-04-27  2017
# 4975                                       Tee Grizzley  2017-04-27  2017
# 4976                                      Lauren Alaina  2017-04-27  2017
# 4977                                   The Chainsmokers  2017-04-27  2017
# 4978                       YFN Lucci Featuring PnB Rock  2017-04-27  2017
# 4979                           Martin Garrix & Dua Lipa  2017-04-27  2017
# 4980                Thomas Rhett Featuring Maren Morris  2017-04-27  2017
# 4981                      2 Chainz x Gucci Mane x Quavo  2017-04-27  2017
# 4982                                             Future  2017-04-27  2017
# 4983                                              Drake  2017-04-27  2017
# 4984                                    Lady Antebellum  2017-04-27  2017
# 4985                                         Dan + Shay  2017-04-27  2017
# 4986                     Nicki Minaj, Drake & Lil Wayne  2017-04-27  2017
# 4987                                              6LACK  2017-04-27  2017
# 4988                              Flo Rida & 99 Percent  2017-04-27  2017
# 4989                                        Michael Ray  2017-04-27  2017
# 4990                                              Drake  2017-04-27  2017
# 4991                                      Kenny Chesney  2017-04-27  2017
# 4992                                     Dwayne Johnson  2017-04-27  2017
# 4993       Machine Gun Kelly Featuring Hailee Steinfeld  2017-04-27  2017
# 4994                       Zayn Featuring PARTYNEXTDOOR  2017-04-27  2017
# 4995  Enrique Iglesias Featuring Descemer Bueno, Zio...  2017-04-27  2017
# 4996                                                AJR  2017-04-27  2017
# 4997                                       Alessia Cara  2017-04-27  2017
# 4998                                      Darius Rucker  2017-04-27  2017
# 4999                                      Cole Swindell  2017-04-27  2017
#
#      Month Day         Lyrics
# 0       05  13  MUSIXMATCH_NA
# 1       05  13  MUSIXMATCH_NA
# 2       05  13  MUSIXMATCH_NA
# 3       05  13  MUSIXMATCH_NA
# 4       05  13  MUSIXMATCH_NA
# 5       05  13  MUSIXMATCH_NA
# 6       05  13  MUSIXMATCH_NA
# 7       05  13  MUSIXMATCH_NA
# 8       05  13  MUSIXMATCH_NA
# 9       05  13  MUSIXMATCH_NA
# 10      05  13  MUSIXMATCH_NA
# 11      05  13  MUSIXMATCH_NA
# 12      05  13  MUSIXMATCH_NA
# 13      05  13  MUSIXMATCH_NA
# 14      05  13  MUSIXMATCH_NA
# 15      05  13  MUSIXMATCH_NA
# 16      05  13  MUSIXMATCH_NA
# 17      05  13  MUSIXMATCH_NA
# 18      05  13  MUSIXMATCH_NA
# 19      05  13  MUSIXMATCH_NA
# 20      05  13  MUSIXMATCH_NA
# 21      05  13  MUSIXMATCH_NA
# 22      05  13  MUSIXMATCH_NA
# 23      05  13  MUSIXMATCH_NA
# 24      05  13  MUSIXMATCH_NA
# 25      05  13  MUSIXMATCH_NA
# 26      05  13  MUSIXMATCH_NA
# 27      05  13  MUSIXMATCH_NA
# 28      05  13  MUSIXMATCH_NA
# 29      05  13  MUSIXMATCH_NA
# ...    ...  ..            ...
# 4970    04  27  MUSIXMATCH_NA
# 4971    04  27  MUSIXMATCH_NA
# 4972    04  27  MUSIXMATCH_NA
# 4973    04  27  MUSIXMATCH_NA
# 4974    04  27  MUSIXMATCH_NA
# 4975    04  27  MUSIXMATCH_NA
# 4976    04  27  MUSIXMATCH_NA
# 4977    04  27  MUSIXMATCH_NA
# 4978    04  27  MUSIXMATCH_NA
# 4979    04  27  MUSIXMATCH_NA
# 4980    04  27  MUSIXMATCH_NA
# 4981    04  27  MUSIXMATCH_NA
# 4982    04  27  MUSIXMATCH_NA
# 4983    04  27  MUSIXMATCH_NA
# 4984    04  27  MUSIXMATCH_NA
# 4985    04  27  MUSIXMATCH_NA
# 4986    04  27  MUSIXMATCH_NA
# 4987    04  27  MUSIXMATCH_NA
# 4988    04  27  MUSIXMATCH_NA
# 4989    04  27  MUSIXMATCH_NA
# 4990    04  27  MUSIXMATCH_NA
# 4991    04  27  MUSIXMATCH_NA
# 4992    04  27  MUSIXMATCH_NA
# 4993    04  27  MUSIXMATCH_NA
# 4994    04  27  MUSIXMATCH_NA
# 4995    04  27  MUSIXMATCH_NA
# 4996    04  27  MUSIXMATCH_NA
# 4997    04  27  MUSIXMATCH_NA
# 4998    04  27  MUSIXMATCH_NA
# 4999    04  27  MUSIXMATCH_NA
#
# [5000 rows x 7 columns]

# %%
# Vader Sentiment Analysis on each song in the dataframe

# INITIALIZE a list to hold the sentiments
lyrics_sentiments = []

# ANALYZE the list
for y in range(len(lyrics_list)):
    results = analyzer.polarity_scores(clean_chart_df.iloc[y,6])
    compound = results["compound"]
    pos = results["pos"]
    neu = results["neu"]
    neg = results["neg"]
    lyrics_sentiments.append({"Compound": compound,
                              "Positive": pos,
                              "Negative": neg,
                              "Neutral": neu})

# CREATE a dataframe of sentiment analysis that will be appended to the chart_df
lyrics_sentiments_df = pd.DataFrame(lyrics_sentiments)    
    
# APPEND new columns containing the sentiment analysis    
clean_chart_df['Compound'] = lyrics_sentiments_df['Compound']
clean_chart_df['Positive'] = lyrics_sentiments_df['Positive']
clean_chart_df['Negative'] = lyrics_sentiments_df['Negative']
clean_chart_df['Neutral'] = lyrics_sentiments_df['Neutral']

# SAVE to a .csv output
clean_chart_df.to_csv('billboard_analysis.csv')

# VIEW resulting dataframe
clean_chart_df

# %%
chart_group = chart_df.groupby(["Year"]).mean()
chart_group_df = pd.DataFrame(chart_group).reset_index(drop=False)
chart_group_df

# %%
plt.rcParams["figure.figsize"] = (20,10)
plt.plot(chart_group_df['Year'], chart_group_df['Negative'], marker="o", linewidth=0 ,alpha=0.8, c='k', label="Negative")
plt.xticks(rotation=90)
plt.ylabel("Negative Sentiment Analysis")
plt.xlabel("Year")
plt.show

# %%
plt.rcParams["figure.figsize"] = (20,10)
plt.plot(chart_group_df['Year'], chart_group_df['Positive'], marker="x", linewidth=0 ,alpha=0.8, c='k', label="Negative")
plt.xticks(rotation=90)
plt.ylabel("Positive Sentiment Analysis")
plt.xlabel("Year")
plt.show

# %%
plt.rcParams["figure.figsize"] = (20,10)
plt.plot(chart_group_df['Year'], chart_group_df['Neutral'], marker="^", linewidth=0 ,alpha=0.8, c='k', label="Negative")
plt.xticks(rotation=90)
plt.ylabel("Neutral Sentiment Analysis")
plt.xlabel("Year")
plt.show

# %%
plt.rcParams["figure.figsize"] = (20,10)
plt.plot(chart_group_df['Year'], chart_group_df['Compound'], marker="s", linewidth=0 ,alpha=0.8, c='k', label="Negative")
plt.xticks(rotation=90)
plt.ylabel("Compound Sentiment Analysis")
plt.xlabel("Year")
plt.show
