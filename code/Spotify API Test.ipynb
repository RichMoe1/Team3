# %%
# Dependency library

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import requests
import pprint
import spotipy.util as util
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from musixmatch import Musixmatch
from musixmatch_api import api_key
from spotify_api import SPOTIPY_CLIENT_ID, SPOTIPY_CLIENT_SECRET, SPOTIPY_REDIRECT_URI, username

# %%
# Import and Initialize Sentiment Analyzer

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Credentials for APIs - these are imported from our config files
# make sure to whitelist "http://google.com" in your Spotify developer panel;

SPOTIPY_CLIENT_ID = SPOTIPY_CLIENT_ID
SPOTIPY_CLIENT_SECRET = SPOTIPY_CLIENT_SECRET
SPOTIPY_REDIRECT_URI = "http://google.com"
musixmatch = Musixmatch(api_key) #your musixmatch api
username = username #your spotify username

# %%
# Create a Spotify query
search_str = input(prompt='what artist do you want to search on: ')

auth = SpotifyClientCredentials(client_id = SPOTIPY_CLIENT_ID, client_secret = SPOTIPY_CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=auth)

result = sp.search(search_str)
pprint.pprint(result)
print(search_str)
# Out:
# what artist do you want to search on: Ben Folds
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Ben+Folds&type=track&offset=0&limit=10',
#             'items': [{'album': {'album_type': 'compilation',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#                                               'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#                                               'id': '0LyfQWJT6nXafLPZqxe9Of',
#                                               'name': 'Various Artists',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#                                  'available_markets': ['AD',
#                                                        'AR',
#                                                        'AT',
#                                                        'AU',
#                                                        'BE',
#                                                        'BG',
#                                                        'BO',
#                                                        'BR',
#                                                        'CA',
#                                                        'CH',
#                                                        'CL',
#                                                        'CO',
#                                                        'CR',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DE',
#                                                        'DK',
#                                                        'DO',
#                                                        'EC',
#                                                        'EE',
#                                                        'ES',
#                                                        'FI',
#                                                        'FR',
#                                                        'GB',
#                                                        'GR',
#                                                        'GT',
#                                                        'HK',
#                                                        'HN',
#                                                        'HU',
#                                                        'ID',
#                                                        'IE',
#                                                        'IL',
#                                                        'IS',
#                                                        'IT',
#                                                        'JP',
#                                                        'LI',
#                                                        'LT',
#                                                        'LU',
#                                                        'LV',
#                                                        'MC',
#                                                        'MT',
#                                                        'MX',
#                                                        'MY',
#                                                        'NI',
#                                                        'NL',
#                                                        'NO',
#                                                        'NZ',
#                                                        'PA',
#                                                        'PE',
#                                                        'PH',
#                                                        'PL',
#                                                        'PT',
#                                                        'PY',
#                                                        'RO',
#                                                        'SE',
#                                                        'SG',
#                                                        'SK',
#                                                        'SV',
#                                                        'TH',
#                                                        'TR',
#                                                        'TW',
#                                                        'US',
#                                                        'UY',
#                                                        'VN',
#                                                        'ZA'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/5AgsHUKFxr5DApRCmulIqJ'},
#                                  'href': 'https://api.spotify.com/v1/albums/5AgsHUKFxr5DApRCmulIqJ',
#                                  'id': '5AgsHUKFxr5DApRCmulIqJ',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/4d055fc4f9a3e4abd2212145b06d8a5c545c4d9c',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/1d2cc36a559e60a2ef67a769261daef587ab5a0b',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/6941a5d95185a5dc12b6e7702e28800f5cc4464e',
#                                              'width': 64}],
#                                  'name': 'The Hamilton Mixtape',
#                                  'release_date': '2016-12-02',
#                                  'release_date_precision': 'day',
#                                  'type': 'album',
#                                  'uri': 'spotify:album:5AgsHUKFxr5DApRCmulIqJ'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3z6Gk257P9jNcZbBXJNX5i'},
#                                     'href': 'https://api.spotify.com/v1/artists/3z6Gk257P9jNcZbBXJNX5i',
#                                     'id': '3z6Gk257P9jNcZbBXJNX5i',
#                                     'name': 'Regina Spektor',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:3z6Gk257P9jNcZbBXJNX5i'},
#                                    {'external_urls': {'spotify': 'https://open.spotify.com/artist/55tif8708yyDQlSjh3Trdu'},
#                                     'href': 'https://api.spotify.com/v1/artists/55tif8708yyDQlSjh3Trdu',
#                                     'id': '55tif8708yyDQlSjh3Trdu',
#                                     'name': 'Ben Folds',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:55tif8708yyDQlSjh3Trdu'}],
#                        'available_markets': ['AD',
#                                              'AR',
#                                              'AT',
#                                              'AU',
#                                              'BE',
#                                              'BG',
#                                              'BO',
#                                              'BR',
#                                              'CA',
#                                              'CH',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DE',
#                                              'DK',
#                                              'DO',
#                                              'EC',
#                                              'EE',
#                                              'ES',
#                                              'FI',
#                                              'FR',
#                                              'GB',
#                                              'GR',
#                                              'GT',
#                                              'HK',
#                                              'HN',
#                                              'HU',
#                                              'ID',
#                                              'IE',
#                                              'IL',
#                                              'IS',
#                                              'IT',
#                                              'JP',
#                                              'LI',
#                                              'LT',
#                                              'LU',
#                                              'LV',
#                                              'MC',
#                                              'MT',
#                                              'MX',
#                                              'MY',
#                                              'NI',
#                                              'NL',
#                                              'NO',
#                                              'NZ',
#                                              'PA',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PT',
#                                              'PY',
#                                              'RO',
#                                              'SE',
#                                              'SG',
#                                              'SK',
#                                              'SV',
#                                              'TH',
#                                              'TR',
#                                              'TW',
#                                              'US',
#                                              'UY',
#                                              'VN',
#                                              'ZA'],
#                        'disc_number': 1,
#                        'duration_ms': 145786,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'USAT21603220'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/1fq4k7G5kYqUvKIuEmFAAo'},
#                        'href': 'https://api.spotify.com/v1/tracks/1fq4k7G5kYqUvKIuEmFAAo',
#                        'id': '1fq4k7G5kYqUvKIuEmFAAo',
#                        'is_local': False,
#                        'name': 'Dear Theodosia (feat. Ben Folds)',
#                        'popularity': 51,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/4734644673d227859f2e09ab1c42baa724ca52dd?cid=17d302e0fc9546329b3445fa434e76d6',
#                        'track_number': 7,
#                        'type': 'track',
#                        'uri': 'spotify:track:1fq4k7G5kYqUvKIuEmFAAo'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/44gRHbEm4Uqa0ykW0rDTNk'},
#                                               'href': 'https://api.spotify.com/v1/artists/44gRHbEm4Uqa0ykW0rDTNk',
#                                               'id': '44gRHbEm4Uqa0ykW0rDTNk',
#                                               'name': 'Ben Folds Five',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:44gRHbEm4Uqa0ykW0rDTNk'}],
#                                  'available_markets': ['AD',
#                                                        'AR',
#                                                        'AT',
#                                                        'AU',
#                                                        'BE',
#                                                        'BG',
#                                                        'BO',
#                                                        'BR',
#                                                        'CA',
#                                                        'CH',
#                                                        'CL',
#                                                        'CO',
#                                                        'CR',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DE',
#                                                        'DK',
#                                                        'DO',
#                                                        'EC',
#                                                        'EE',
#                                                        'ES',
#                                                        'FI',
#                                                        'FR',
#                                                        'GB',
#                                                        'GR',
#                                                        'GT',
#                                                        'HK',
#                                                        'HN',
#                                                        'HU',
#                                                        'ID',
#                                                        'IE',
#                                                        'IL',
#                                                        'IS',
#                                                        'IT',
#                                                        'JP',
#                                                        'LI',
#                                                        'LT',
#                                                        'LU',
#                                                        'LV',
#                                                        'MC',
#                                                        'MT',
#                                                        'MX',
#                                                        'MY',
#                                                        'NI',
#                                                        'NL',
#                                                        'NO',
#                                                        'NZ',
#                                                        'PA',
#                                                        'PE',
#                                                        'PH',
#                                                        'PL',
#                                                        'PT',
#                                                        'PY',
#                                                        'RO',
#                                                        'SE',
#                                                        'SG',
#                                                        'SK',
#                                                        'SV',
#                                                        'TH',
#                                                        'TR',
#                                                        'TW',
#                                                        'US',
#                                                        'UY',
#                                                        'VN',
#                                                        'ZA'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/3oz8kworUyU7oXjaEVhDsZ'},
#                                  'href': 'https://api.spotify.com/v1/albums/3oz8kworUyU7oXjaEVhDsZ',
#                                  'id': '3oz8kworUyU7oXjaEVhDsZ',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/8ff64c89950a4b3584bec7263328a62a68d97c30',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/0e3ada0162c2376a5c63654262d21516184e6f1a',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/dc3733dac4009f334b2565fa6e06c9cff66849d2',
#                                              'width': 64}],
#                                  'name': 'Whatever And Ever Amen (Remastered '
#                                          'Edition)',
#                                  'release_date': '1997-03-18',
#                                  'release_date_precision': 'day',
#                                  'type': 'album',
#                                  'uri': 'spotify:album:3oz8kworUyU7oXjaEVhDsZ'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/44gRHbEm4Uqa0ykW0rDTNk'},
#                                     'href': 'https://api.spotify.com/v1/artists/44gRHbEm4Uqa0ykW0rDTNk',
#                                     'id': '44gRHbEm4Uqa0ykW0rDTNk',
#                                     'name': 'Ben Folds Five',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:44gRHbEm4Uqa0ykW0rDTNk'}],
#                        'available_markets': ['AD',
#                                              'AR',
#                                              'AT',
#                                              'AU',
#                                              'BE',
#                                              'BG',
#                                              'BO',
#                                              'BR',
#                                              'CA',
#                                              'CH',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DE',
#                                              'DK',
#                                              'DO',
#                                              'EC',
#                                              'EE',
#                                              'ES',
#                                              'FI',
#                                              'FR',
#                                              'GB',
#                                              'GR',
#                                              'GT',
#                                              'HK',
#                                              'HN',
#                                              'HU',
#                                              'ID',
#                                              'IE',
#                                              'IL',
#                                              'IS',
#                                              'IT',
#                                              'JP',
#                                              'LI',
#                                              'LT',
#                                              'LU',
#                                              'LV',
#                                              'MC',
#                                              'MT',
#                                              'MX',
#                                              'MY',
#                                              'NI',
#                                              'NL',
#                                              'NO',
#                                              'NZ',
#                                              'PA',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PT',
#                                              'PY',
#                                              'RO',
#                                              'SE',
#                                              'SG',
#                                              'SK',
#                                              'SV',
#                                              'TH',
#                                              'TR',
#                                              'TW',
#                                              'US',
#                                              'UY',
#                                              'VN',
#                                              'ZA'],
#                        'disc_number': 1,
#                        'duration_ms': 271720,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'USSM19603695'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/4jKq1e80xAYixkIwt6YyV1'},
#                        'href': 'https://api.spotify.com/v1/tracks/4jKq1e80xAYixkIwt6YyV1',
#                        'id': '4jKq1e80xAYixkIwt6YyV1',
#                        'is_local': False,
#                        'name': 'Brick',
#                        'popularity': 55,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/b28c4c6add13d7698782ddf2774619318875d57e?cid=17d302e0fc9546329b3445fa434e76d6',
#                        'track_number': 3,
#                        'type': 'track',
#                        'uri': 'spotify:track:4jKq1e80xAYixkIwt6YyV1'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/55tif8708yyDQlSjh3Trdu'},
#                                               'href': 'https://api.spotify.com/v1/artists/55tif8708yyDQlSjh3Trdu',
#                                               'id': '55tif8708yyDQlSjh3Trdu',
#                                               'name': 'Ben Folds',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:55tif8708yyDQlSjh3Trdu'}],
#                                  'available_markets': ['AD',
#                                                        'AR',
#                                                        'AU',
#                                                        'BE',
#                                                        'BG',
#                                                        'BO',
#                                                        'BR',
#                                                        'CA',
#                                                        'CL',
#                                                        'CO',
#                                                        'CR',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DK',
#                                                        'DO',
#                                                        'EC',
#                                                        'EE',
#                                                        'ES',
#                                                        'FI',
#                                                        'FR',
#                                                        'GB',
#                                                        'GR',
#                                                        'GT',
#                                                        'HK',
#                                                        'HN',
#                                                        'HU',
#                                                        'ID',
#                                                        'IE',
#                                                        'IL',
#                                                        'IS',
#                                                        'IT',
#                                                        'JP',
#                                                        'LT',
#                                                        'LU',
#                                                        'LV',
#                                                        'MC',
#                                                        'MT',
#                                                        'MX',
#                                                        'MY',
#                                                        'NI',
#                                                        'NL',
#                                                        'NO',
#                                                        'NZ',
#                                                        'PA',
#                                                        'PE',
#                                                        'PH',
#                                                        'PL',
#                                                        'PT',
#                                                        'PY',
#                                                        'RO',
#                                                        'SE',
#                                                        'SG',
#                                                        'SK',
#                                                        'SV',
#                                                        'TH',
#                                                        'TR',
#                                                        'TW',
#                                                        'US',
#                                                        'UY',
#                                                        'VN',
#                                                        'ZA'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/4FtOLTQqwnxpaABrJWYdBy'},
#                                  'href': 'https://api.spotify.com/v1/albums/4FtOLTQqwnxpaABrJWYdBy',
#                                  'id': '4FtOLTQqwnxpaABrJWYdBy',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/3f402c6c8d3aa46ee6cad2fc784d98cba4eba83e',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/dddb3343ebf02eb17418dc51adc6a2860c65373b',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/7e4a23645ac5d166912b65a85db13f5ac099d38e',
#                                              'width': 64}],
#                                  'name': "Rockin' The Suburbs",
#                                  'release_date': '2001-09-11',
#                                  'release_date_precision': 'day',
#                                  'type': 'album',
#                                  'uri': 'spotify:album:4FtOLTQqwnxpaABrJWYdBy'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/55tif8708yyDQlSjh3Trdu'},
#                                     'href': 'https://api.spotify.com/v1/artists/55tif8708yyDQlSjh3Trdu',
#                                     'id': '55tif8708yyDQlSjh3Trdu',
#                                     'name': 'Ben Folds',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:55tif8708yyDQlSjh3Trdu'}],
#                        'available_markets': ['AD',
#                                              'AR',
#                                              'AU',
#                                              'BE',
#                                              'BG',
#                                              'BO',
#                                              'BR',
#                                              'CA',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DK',
#                                              'DO',
#                                              'EC',
#                                              'EE',
#                                              'ES',
#                                              'FI',
#                                              'FR',
#                                              'GB',
#                                              'GR',
#                                              'GT',
#                                              'HK',
#                                              'HN',
#                                              'HU',
#                                              'ID',
#                                              'IE',
#                                              'IL',
#                                              'IS',
#                                              'IT',
#                                              'JP',
#                                              'LT',
#                                              'LU',
#                                              'LV',
#                                              'MC',
#                                              'MT',
#                                              'MX',
#                                              'MY',
#                                              'NI',
#                                              'NL',
#                                              'NO',
#                                              'NZ',
#                                              'PA',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PT',
#                                              'PY',
#                                              'RO',
#                                              'SE',
#                                              'SG',
#                                              'SK',
#                                              'SV',
#                                              'TH',
#                                              'TR',
#                                              'TW',
#                                              'US',
#                                              'UY',
#                                              'VN',
#                                              'ZA'],
#                        'disc_number': 1,
#                        'duration_ms': 265293,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'USSM10105180'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/1fujSajijBpJlr5mRGKHJN'},
#                        'href': 'https://api.spotify.com/v1/tracks/1fujSajijBpJlr5mRGKHJN',
#                        'id': '1fujSajijBpJlr5mRGKHJN',
#                        'is_local': False,
#                        'name': 'The Luckiest',
#                        'popularity': 47,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/850777034e3253a6c5395f5c1be654503edd6b64?cid=17d302e0fc9546329b3445fa434e76d6',
#                        'track_number': 12,
#                        'type': 'track',
#                        'uri': 'spotify:track:1fujSajijBpJlr5mRGKHJN'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/55tif8708yyDQlSjh3Trdu'},
#                                               'href': 'https://api.spotify.com/v1/artists/55tif8708yyDQlSjh3Trdu',
#                                               'id': '55tif8708yyDQlSjh3Trdu',
#                                               'name': 'Ben Folds',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:55tif8708yyDQlSjh3Trdu'}],
#                                  'available_markets': ['AD',
#                                                        'AR',
#                                                        'AU',
#                                                        'BG',
#                                                        'BO',
#                                                        'BR',
#                                                        'CL',
#                                                        'CO',
#                                                        'CR',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DK',
#                                                        'DO',
#                                                        'EC',
#                                                        'EE',
#                                                        'ES',
#                                                        'FI',
#                                                        'FR',
#                                                        'GR',
#                                                        'GT',
#                                                        'HK',
#                                                        'HN',
#                                                        'HU',
#                                                        'ID',
#                                                        'IE',
#                                                        'IL',
#                                                        'IS',
#                                                        'IT',
#                                                        'JP',
#                                                        'LT',
#                                                        'LV',
#                                                        'MC',
#                                                        'MT',
#                                                        'MX',
#                                                        'MY',
#                                                        'NI',
#                                                        'NO',
#                                                        'NZ',
#                                                        'PA',
#                                                        'PE',
#                                                        'PH',
#                                                        'PL',
#                                                        'PT',
#                                                        'PY',
#                                                        'RO',
#                                                        'SE',
#                                                        'SG',
#                                                        'SK',
#                                                        'SV',
#                                                        'TH',
#                                                        'TR',
#                                                        'TW',
#                                                        'US',
#                                                        'UY',
#                                                        'VN',
#                                                        'ZA'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/3V8q5Mi44jT2wvKyaMVM3x'},
#                                  'href': 'https://api.spotify.com/v1/albums/3V8q5Mi44jT2wvKyaMVM3x',
#                                  'id': '3V8q5Mi44jT2wvKyaMVM3x',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/7b3af84c7c620cc0b9798ca445ac7feef724145f',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/be88e4cac2f0f45b8e4cec18483b6a8e0805d0ed',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/e4c507278a97a2a035c8a46712569e646ed2386a',
#                                              'width': 64}],
#                                  'name': 'Way To Normal',
#                                  'release_date': '2008-09-29',
#                                  'release_date_precision': 'day',
#                                  'type': 'album',
#                                  'uri': 'spotify:album:3V8q5Mi44jT2wvKyaMVM3x'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/55tif8708yyDQlSjh3Trdu'},
#                                     'href': 'https://api.spotify.com/v1/artists/55tif8708yyDQlSjh3Trdu',
#                                     'id': '55tif8708yyDQlSjh3Trdu',
#                                     'name': 'Ben Folds',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:55tif8708yyDQlSjh3Trdu'}],
#                        'available_markets': ['AD',
#                                              'AR',
#                                              'AU',
#                                              'BG',
#                                              'BO',
#                                              'BR',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DK',
#                                              'DO',
#                                              'EC',
#                                              'EE',
#                                              'ES',
#                                              'FI',
#                                              'FR',
#                                              'GR',
#                                              'GT',
#                                              'HK',
#                                              'HN',
#                                              'HU',
#                                              'ID',
#                                              'IE',
#                                              'IL',
#                                              'IS',
#                                              'IT',
#                                              'JP',
#                                              'LT',
#                                              'LV',
#                                              'MC',
#                                              'MT',
#                                              'MX',
#                                              'MY',
#                                              'NI',
#                                              'NO',
#                                              'NZ',
#                                              'PA',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PT',
#                                              'PY',
#                                              'RO',
#                                              'SE',
#                                              'SG',
#                                              'SK',
#                                              'SV',
#                                              'TH',
#                                              'TR',
#                                              'TW',
#                                              'US',
#                                              'UY',
#                                              'VN',
#                                              'ZA'],
#                        'disc_number': 1,
#                        'duration_ms': 189693,
#                        'explicit': True,
#                        'external_ids': {'isrc': 'USSM10802782'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/1rihwqlxLr1kL7zg5193FF'},
#                        'href': 'https://api.spotify.com/v1/tracks/1rihwqlxLr1kL7zg5193FF',
#                        'id': '1rihwqlxLr1kL7zg5193FF',
#                        'is_local': False,
#                        'name': "You Don't Know Me (featuring Regina Spektor) - "
#                                'Explicit Album Version',
#                        'popularity': 46,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/f657d95d9fc6b7e58afc33901937eff619ef22bf?cid=17d302e0fc9546329b3445fa434e76d6',
#                        'track_number': 4,
#                        'type': 'track',
#                        'uri': 'spotify:track:1rihwqlxLr1kL7zg5193FF'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/44gRHbEm4Uqa0ykW0rDTNk'},
#                                               'href': 'https://api.spotify.com/v1/artists/44gRHbEm4Uqa0ykW0rDTNk',
#                                               'id': '44gRHbEm4Uqa0ykW0rDTNk',
#                                               'name': 'Ben Folds Five',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:44gRHbEm4Uqa0ykW0rDTNk'}],
#                                  'available_markets': ['AD',
#                                                        'AR',
#                                                        'AT',
#                                                        'AU',
#                                                        'BE',
#                                                        'BG',
#                                                        'BO',
#                                                        'BR',
#                                                        'CA',
#                                                        'CH',
#                                                        'CL',
#                                                        'CO',
#                                                        'CR',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DE',
#                                                        'DK',
#                                                        'DO',
#                                                        'EC',
#                                                        'EE',
#                                                        'ES',
#                                                        'FI',
#                                                        'FR',
#                                                        'GB',
#                                                        'GR',
#                                                        'GT',
#                                                        'HK',
#                                                        'HN',
#                                                        'HU',
#                                                        'ID',
#                                                        'IE',
#                                                        'IL',
#                                                        'IS',
#                                                        'IT',
#                                                        'JP',
#                                                        'LI',
#                                                        'LT',
#                                                        'LU',
#                                                        'LV',
#                                                        'MC',
#                                                        'MT',
#                                                        'MX',
#                                                        'MY',
#                                                        'NI',
#                                                        'NL',
#                                                        'NO',
#                                                        'NZ',
#                                                        'PA',
#                                                        'PE',
#                                                        'PH',
#                                                        'PL',
#                                                        'PT',
#                                                        'PY',
#                                                        'RO',
#                                                        'SE',
#                                                        'SG',
#                                                        'SK',
#                                                        'SV',
#                                                        'TH',
#                                                        'TR',
#                                                        'TW',
#                                                        'US',
#                                                        'UY',
#                                                        'VN',
#                                                        'ZA'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/2zNa1aZ0VaGfuiNqDbrQET'},
#                                  'href': 'https://api.spotify.com/v1/albums/2zNa1aZ0VaGfuiNqDbrQET',
#                                  'id': '2zNa1aZ0VaGfuiNqDbrQET',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/173b0dbcae1c082a1a32093314515e8fd747ea1b',
#                                              'width': 638},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/d40450d08bdcf36f7fcd44ada2b16ae6fb7dde53',
#                                              'width': 299},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/8e4b17aa462def726eef7423bcfd28d9c9c09d28',
#                                              'width': 64}],
#                                  'name': 'Ben Folds Five',
#                                  'release_date': '1995-08-08',
#                                  'release_date_precision': 'day',
#                                  'type': 'album',
#                                  'uri': 'spotify:album:2zNa1aZ0VaGfuiNqDbrQET'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/44gRHbEm4Uqa0ykW0rDTNk'},
#                                     'href': 'https://api.spotify.com/v1/artists/44gRHbEm4Uqa0ykW0rDTNk',
#                                     'id': '44gRHbEm4Uqa0ykW0rDTNk',
# ...
#                                  'name': 'Ben Folds Live',
#                                  'release_date': '2002-10-08',
#                                  'release_date_precision': 'day',
#                                  'type': 'album',
#                                  'uri': 'spotify:album:2DgQmqmJ5PH34rErXoUhK8'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/55tif8708yyDQlSjh3Trdu'},
#                                     'href': 'https://api.spotify.com/v1/artists/55tif8708yyDQlSjh3Trdu',
#                                     'id': '55tif8708yyDQlSjh3Trdu',
#                                     'name': 'Ben Folds',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:55tif8708yyDQlSjh3Trdu'}],
#                        'available_markets': ['AD',
#                                              'AR',
#                                              'AT',
#                                              'AU',
#                                              'BE',
#                                              'BG',
#                                              'BO',
#                                              'BR',
#                                              'CA',
#                                              'CH',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DE',
#                                              'DK',
#                                              'DO',
#                                              'EC',
#                                              'EE',
#                                              'ES',
#                                              'FI',
#                                              'FR',
#                                              'GB',
#                                              'GR',
#                                              'GT',
#                                              'HK',
#                                              'HN',
#                                              'HU',
#                                              'ID',
#                                              'IE',
#                                              'IL',
#                                              'IS',
#                                              'IT',
#                                              'JP',
#                                              'LI',
#                                              'LT',
#                                              'LU',
#                                              'LV',
#                                              'MC',
#                                              'MT',
#                                              'MX',
#                                              'MY',
#                                              'NI',
#                                              'NL',
#                                              'NO',
#                                              'NZ',
#                                              'PA',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PT',
#                                              'PY',
#                                              'RO',
#                                              'SE',
#                                              'SG',
#                                              'SK',
#                                              'SV',
#                                              'TH',
#                                              'TR',
#                                              'TW',
#                                              'US',
#                                              'UY',
#                                              'VN',
#                                              'ZA'],
#                        'disc_number': 1,
#                        'duration_ms': 323600,
#                        'explicit': True,
#                        'external_ids': {'isrc': 'USSM10211087'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/6QMujKWzo7QpC39f7M9tzV'},
#                        'href': 'https://api.spotify.com/v1/tracks/6QMujKWzo7QpC39f7M9tzV',
#                        'id': '6QMujKWzo7QpC39f7M9tzV',
#                        'is_local': False,
#                        'name': 'Tiny Dancer - Live at the Newport Music '
#                                'Festival, Newport, RI - July 2002',
#                        'popularity': 39,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/43b3ff995ca5e3ae79eb06b890996a6a9dc160ce?cid=17d302e0fc9546329b3445fa434e76d6',
#                        'track_number': 13,
#                        'type': 'track',
#                        'uri': 'spotify:track:6QMujKWzo7QpC39f7M9tzV'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/44gRHbEm4Uqa0ykW0rDTNk'},
#                                               'href': 'https://api.spotify.com/v1/artists/44gRHbEm4Uqa0ykW0rDTNk',
#                                               'id': '44gRHbEm4Uqa0ykW0rDTNk',
#                                               'name': 'Ben Folds Five',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:44gRHbEm4Uqa0ykW0rDTNk'}],
#                                  'available_markets': ['AD',
#                                                        'AR',
#                                                        'AT',
#                                                        'AU',
#                                                        'BE',
#                                                        'BG',
#                                                        'BO',
#                                                        'BR',
#                                                        'CA',
#                                                        'CH',
#                                                        'CL',
#                                                        'CO',
#                                                        'CR',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DE',
#                                                        'DK',
#                                                        'DO',
#                                                        'EC',
#                                                        'EE',
#                                                        'ES',
#                                                        'FI',
#                                                        'FR',
#                                                        'GB',
#                                                        'GR',
#                                                        'GT',
#                                                        'HK',
#                                                        'HN',
#                                                        'HU',
#                                                        'ID',
#                                                        'IE',
#                                                        'IL',
#                                                        'IS',
#                                                        'IT',
#                                                        'JP',
#                                                        'LI',
#                                                        'LT',
#                                                        'LU',
#                                                        'LV',
#                                                        'MC',
#                                                        'MT',
#                                                        'MX',
#                                                        'MY',
#                                                        'NI',
#                                                        'NL',
#                                                        'NO',
#                                                        'NZ',
#                                                        'PA',
#                                                        'PE',
#                                                        'PH',
#                                                        'PL',
#                                                        'PT',
#                                                        'PY',
#                                                        'RO',
#                                                        'SE',
#                                                        'SG',
#                                                        'SK',
#                                                        'SV',
#                                                        'TH',
#                                                        'TR',
#                                                        'TW',
#                                                        'US',
#                                                        'UY',
#                                                        'VN',
#                                                        'ZA'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/2ucnrprKK7JaOSaFl1dNGA'},
#                                  'href': 'https://api.spotify.com/v1/albums/2ucnrprKK7JaOSaFl1dNGA',
#                                  'id': '2ucnrprKK7JaOSaFl1dNGA',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/577a852944fa7c8f661897eb84144bca0997d134',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/0cd5228d0bdab82aaba3a42330b18ccc9f2f87ab',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/683bbb2945f77061ded58ad0443446930ffc5c44',
#                                              'width': 64}],
#                                  'name': 'The Unauthorized Biography Of '
#                                          'Reinhold Messner',
#                                  'release_date': '1999-04-27',
#                                  'release_date_precision': 'day',
#                                  'type': 'album',
#                                  'uri': 'spotify:album:2ucnrprKK7JaOSaFl1dNGA'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/44gRHbEm4Uqa0ykW0rDTNk'},
#                                     'href': 'https://api.spotify.com/v1/artists/44gRHbEm4Uqa0ykW0rDTNk',
#                                     'id': '44gRHbEm4Uqa0ykW0rDTNk',
#                                     'name': 'Ben Folds Five',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:44gRHbEm4Uqa0ykW0rDTNk'}],
#                        'available_markets': ['AD',
#                                              'AR',
#                                              'AT',
#                                              'AU',
#                                              'BE',
#                                              'BG',
#                                              'BO',
#                                              'BR',
#                                              'CA',
#                                              'CH',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DE',
#                                              'DK',
#                                              'DO',
#                                              'EC',
#                                              'EE',
#                                              'ES',
#                                              'FI',
#                                              'FR',
#                                              'GB',
#                                              'GR',
#                                              'GT',
#                                              'HK',
#                                              'HN',
#                                              'HU',
#                                              'ID',
#                                              'IE',
#                                              'IL',
#                                              'IS',
#                                              'IT',
#                                              'JP',
#                                              'LI',
#                                              'LT',
#                                              'LU',
#                                              'LV',
#                                              'MC',
#                                              'MT',
#                                              'MX',
#                                              'MY',
#                                              'NI',
#                                              'NL',
#                                              'NO',
#                                              'NZ',
#                                              'PA',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PT',
#                                              'PY',
#                                              'RO',
#                                              'SE',
#                                              'SG',
#                                              'SK',
#                                              'SV',
#                                              'TH',
#                                              'TR',
#                                              'TW',
#                                              'US',
#                                              'UY',
#                                              'VN',
#                                              'ZA'],
#                        'disc_number': 1,
#                        'duration_ms': 203160,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'USSM19900210'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/3vxqxKLhQDG8BOu65tXi8g'},
#                        'href': 'https://api.spotify.com/v1/tracks/3vxqxKLhQDG8BOu65tXi8g',
#                        'id': '3vxqxKLhQDG8BOu65tXi8g',
#                        'is_local': False,
#                        'name': 'Army',
#                        'popularity': 43,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/b1c9ee0df444e15a733713e2652b3255f12678f7?cid=17d302e0fc9546329b3445fa434e76d6',
#                        'track_number': 6,
#                        'type': 'track',
#                        'uri': 'spotify:track:3vxqxKLhQDG8BOu65tXi8g'}],
#             'limit': 10,
#             'next': 'https://api.spotify.com/v1/search?query=Ben+Folds&type=track&offset=10&limit=10',
#             'offset': 0,
#             'previous': None,
#             'total': 587}}
# Ben Folds

# %%
# MUSIXMATCH
# source: https://developer.musixmatch.com/documentation/api-reference/track-lyrics-get
# python: https://github.com/hudsonbrendon/python-musixmatch

# required parameters for chart_tracks_get method ''page', 'page_size', and 'f_has_lyrics''
mmsearch = musixmatch.chart_tracks_get(page=1, page_size=1, f_has_lyrics=True)
track_id = mmsearch['message']['body']['track_list'][0]['track']['track_id']
track_id
# Out:
# 152383631

# %%
# MUSIXMATCH lyrics search based on the "Track ID" from previous block

track_test = musixmatch.track_lyrics_get(track_id)['message']['body']['lyrics']['lyrics_body']
track_test
# Out:
# "Trap, TrapMoneyBenny\nThis shit got me in my feelings\nGotta be real with it, yup\n\nKiki, do you love me? Are you riding?\nSay you'll never ever leave from beside me\n'Cause I want ya, and I need ya\nAnd I'm down for you always\nKB, do you love me? Are you riding?\nSay you'll never ever leave from beside me\n'Cause I want ya, and I need ya\nAnd I'm down for you always\n\nLook, the new me is really still the real me\nI swear you gotta feel me before they try and kill me\nThey gotta make some choices, they runnin' out of options\n'Cause I've been goin' off and they don't know when it's stoppin'\nAnd when you get to toppin', I see that you've been learnin'\nAnd when I take you shoppin', you spend it like you earned it\nAnd when you popped off on your ex, he deserved it\nI thought you were the one from the jump that confirmed it\n\nTrapMoneyBenny\nI buy you Champagne but you love some Henny\nFrom the block, like you Jenny\nI know you special, girl, 'cause I know too many\n...\n\n******* This Lyrics is NOT for Commercial use *******\n(1409617829201)"

# %%
# Truncate the nonsense at the end of the lyrics from MusixMatch
song_length = len(track_test)
endpoint = len("******* This Lyrics is NOT for Commercial use *******\n(1409617829201)")
track_test.replace("\n", ". ")
track_test = track_test[:song_length-endpoint]
print(track_test)
# Out:
# Trap, TrapMoneyBenny
# This shit got me in my feelings
# Gotta be real with it, yup
#
# Kiki, do you love me? Are you riding?
# Say you'll never ever leave from beside me
# 'Cause I want ya, and I need ya
# And I'm down for you always
# KB, do you love me? Are you riding?
# Say you'll never ever leave from beside me
# 'Cause I want ya, and I need ya
# And I'm down for you always
#
# Look, the new me is really still the real me
# I swear you gotta feel me before they try and kill me
# They gotta make some choices, they runnin' out of options
# 'Cause I've been goin' off and they don't know when it's stoppin'
# And when you get to toppin', I see that you've been learnin'
# And when I take you shoppin', you spend it like you earned it
# And when you popped off on your ex, he deserved it
# I thought you were the one from the jump that confirmed it
#
# TrapMoneyBenny
# I buy you Champagne but you love some Henny
# From the block, like you Jenny
# I know you special, girl, 'cause I know too many
# ...

# %%
# Vader Sentiment Analysis on the song selected

results = analyzer.polarity_scores(track_test)
compound = results["compound"]
pos = results["pos"]
neu = results["neu"]
neg = results["neg"]

print(pos)
print(neu)
print(neg)
print(compound)
# Out:
# 0.129
# 0.813
# 0.057
# 0.9154
